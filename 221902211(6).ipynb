# %%
string in python

str.function():

# %%
S = 'Hello World'
print(len(S))
print(S.upper())
print(S.capitalize())
print(S.lower())
print(S.replace('world', 'python'))
# Out:
# 11
# HELLO WORLD
# Hello world
# hello world
# Hello World

# %%
s = ' Hlw wrld '
print(s.strip())
print(s.rstrip())
print(s.lstrip())
# Out:
# Hlw wrld
#  Hlw wrld
# Hlw wrld

# %%
s = 'Hello World'
print(s.find('world'))
print(s.find('Sajib'))
print(s.find('World'))
print(s.find('Hello'))
print(s.find('o'))
# Out:
# -1
# -1
# 6
# 0
# 4

# %%
s = "Jamil Hasan Sajib"
print(s.startswith('Jamil'))
print(s.startswith("sajib"))
print(s.startswith("Sajib"))
print(s.startswith("h"))
# Out:
# True
# False
# False
# False

# %%
s = "Jamil Hasan Sajib"
print(s.endswith('Jamil'))
print(s.endswith('Sajib'))
# Out:
# False
# True

# %%
A = [1, 2, 3, 4]

print(A.join)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-1788ce7b3dd5> in <cell line: 2>()
#       1 A = [1, 2, 3, 4]
# ----> 2 print(A.join)
#
# AttributeError: 'list' object has no attribute 'join'

# %%
s = "12345"
t = "abc123"
print(s.isdigit())
print(t.isdigit())
# Out:
# True
# False

# %%
a = '1234'
b = 'sajib1234'
print(a.isdigit())
print(b.isdigit())
# Out:
# True
# False

# %%
text = 'Hello World'
st = text.split()
print(st)
jst = " ".join(text)
print(jst)
A = ['how', 'are', 'you' '?']
print(" ".join(A))
rst = st[::-1]
print(rst)
# Out:
# ['Hello', 'World']
# H e l l o   W o r l d
# how are you?
# ['World', 'Hello']
