# %% [markdown]
# Function in Python
#
# *Readability
# *Saves time of writing code again and again
# *Shorting length of code
#
# Modular or short group
#
# There are 2 types function
# 1. Redimate or Buit in Function
# *input
# *print
#
# 2. User defined function
#
#
# #How to write a function
#
# def function_Name():
#     print("Hello World")

# %%
def Factorial():
  n = int(input("put the number"))
  fact = 1
  for i in range (1, n+1, 1):
    fact*=i
    print(fact)

Factorial()
Factorial()
# Out:
# put the number23
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880
# 3628800
# 39916800
# 479001600
# 6227020800
# 87178291200
# 1307674368000
# 20922789888000
# 355687428096000
# 6402373705728000
# 121645100408832000
# 2432902008176640000
# 51090942171709440000
# 1124000727777607680000
# 25852016738884976640000
# put the number3
# 1
# 2
# 6

# %%
n = 2345
word = "hello"
print(int(str(n)[::-1]))
# Out:
# 5432

# %%
Word = 'hello'
print(str(word)[::-1])
# Out:
# olleh

# %%
def GreatestNumber():
  a = int(input("put a number: "))
  b = int(input("put a number: "))
  c = int(input("put a number: "))

  if a > b:
      if a > c:
          print(a, 'is the greatest number')
      else:
          print(c, 'is the greatest number')
  else:
      if b > c:
          print(b, 'is the greatest number')
      else:
          print(c, 'is the greatest number')

GreatestNumber()
# Out:
# put a number: 3
# put a number: 4
# put a number: 6
# 6 is the greatest number

# %%
def Example (num, num2):
  print (num, num2)

Example(34, 45)
# Out:
# 34 45

# %%
def GreatestNumber(a, b, c):

  if a > b:
      if a > c:
          print(a, 'is the greatest number')
      else:
          print(c, 'is the greatest number')
  else:
      if b > c:
          print(b, 'is the greatest number')
      else:
          print(c, 'is the greatest number')

GreatestNumber(10, 20, 30)
# Out:
# 30 is the greatest number

# %%
def Factorial(n):
  fact = 1
  for i in range (1, n+1, 1):
    fact*=i
    print(fact)

Factorial(3)
# Out:
# 1
# 2
# 6

# %%
def Example (num, num2):
  print (num, num2)

Example(num2 = 34, num = 45)
# Out:
# 45 34

# %%
def Example (num, num2 = 32):
  print (num, num2)

Example(num = 34, num2 = 56)
# Out:
# 34 56

# %%
def Example (num, num2 = 32):
  print (num, num2)

Example(num = 34)
# Out:
# 34 32

# %%
def CircleArea(r):
  pi = 3.1416
  print(pi*r*r)
CircleArea(2)

def SquareArea(a, b):
    print(a*b)
SquareArea(10, 10)
# Out:
# 12.5664
# 100

# %%
def CountingCharacters(sentence):
  sentence = (input('Write the Line: '))
  return len(sentence)

# %%
import math
def CircleArea(r):
  return math.pi*r*r
CircleArea(2)
# Out:
# 12.566370614359172

# %%
def SquareArea(side):
  return side*side
SquareArea(20)
# Out:
# 400

# %%
def exp():
    return 4, 5, "hello"
    a, b, c = exp()
print(a, b, c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-0cf92e6cf1ad> in <cell line: 4>()
#       2     return 4, 5, "hello"
#       3     a, b, c = exp()
# ----> 4 print(a, b, c)
#
# NameError: name 'a' is not defined

# %%
#Global
a = 10

# %%
print(a)
# Out:
# 10

# %%
def exp():
  b = 10

# %%
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-67e500defa1b> in <cell line: 1>()
# ----> 1 print(b)
#
# NameError: name 'b' is not defined

# %%
Addition = lambda a, b: a+b
print(Addition(5, 6))
# Out:
# 11

# %%
fn = "Sajib"
ln = "Kazi"

print(fn, ln)
print(f'first Name: {fn}, Last Name: {ln}')
# Out:
# Sajib Kazi
# first Name: Sajib, Last Name: Kazi

# %%
FirstName = input("put your first Name: ")
LastName = input("put your Last Name: ")
FullName = lambda fn, ln: f'{fn} {ln}'
print(f'first Name: {fn}, Last Name: {ln}')
# Out:
# put your first Name: Sajib
# put your Last Name: Kazi
# first Name: Sajib, Last Name: Kazi

# %%
userid = "sajib2345"
