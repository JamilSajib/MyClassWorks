# %%
print(123)
print("Hello World")
x = 12.2
y = 14
print(x)
print(y)
print(x,y)
print('x: ', x, 'y: ', y)
print("x: "+str(x), "y: "+str(y))
print(x)
PI = 3.1416
redius = 3.2
Area = PI*redius**2
print(Area)
a=10
b=20
a,b=b,a
print(a, b)
principle = 30000
Rate_of_Interest = 5
Time = 5 #In year
Interest = principle*Rate_of_Interest*Time
print('The Interest: ', Interest)
Celsius = 37
Fahrenheit= (Celsius*9/50) + 32
print(Fahrenheit)
Length = 3.3
Width = 4.2
Area = Length*Width
Perimeter = 2*(Length+Width)
print(Area, Perimeter)
# Out:
# 123
# Hello World
# 12.2
# 14
# 12.2 14
# x:  12.2 y:  14
# x: 12.2 y: 14
# 12.2
# 32.16998400000001
# 20 10
# The Interest:  750000
# 38.66
# 13.86 15.0

# %%
noun = 'Sajib'
Day = 'Monday'

str_ = f'''How are you Mr. {noun}? You are invited to my on {Day}.'''

print(str_)
# Out:
# How are you Mr. Sajib? You are invited to my on Monday.

# %%
Hours = int (input("Put the content: "))
Rate = float(input("Put the rate: "))
Pay = Hours*Rate
print("The gross pay is: ", Pay)
# Out:
# Put the content: 35
# Put the rate: 2.75
# The gross pay is:  96.25

# %%
print (n = 7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-30979dac51c1> in <cell line: 1>()
# ----> 1 print (n = 7)
#
# TypeError: 'n' is an invalid keyword argument for print()

# %%
print(7+5)
# Out:
# 12

# %%
print (5.2, "this", 4 - 2, "that", 5/2.0)
# Out:
# 5.2 this 2 that 2.5

# %%
6 * (1 - 2)
# Out:
# -6

# %%
noun1=input("Enter a name: ")

noun2 = input("Enter another noun: ")

plural_noun = input("Enter a plural noun: ")

verb_past = input("Enter a verb in past tense: ")

verb = input("Enter a verb: ")

adjective = input("Enter an adjective: ")

adverb = input("Enter an adverb: ")

story = f'''My name is {noun1}, and my father name is {noun2}. We {verb_past} some {adjective} {plural_noun}, where we can {verb} many lession {adverb}.'''

print(story)
# Out:
# Enter a name: Sajib
# Enter another noun: Hisham
# Enter a plural noun: schools
# Enter a verb in past tense: made
# Enter a verb: achieve
# Enter an adjective: explicitly
# Enter an adverb: explicitly
# My name is Sajib, and my father name is Hisham. We made some explicitly schools, where we can achieve many lession explicitly.

# %%
a = input("Enter Name: ")
b = input("Enter age: ")
c = 'beautiful'

story = f'''My name is {a}. I am {b} years old. I am a {c} guy.'''
print(story)
# Out:
# Enter Name: Sajib
# Enter age: 23
# My name is Sajib. I am 23 years old. I am a beautiful guy.

# %%
pi = 3.1416
redius = 3.2

area = pi*redius**2
print(area)
# Out:
# 32.16998400000001
